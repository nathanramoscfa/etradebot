# %% [markdown]
# # Model Testing

# %%
import pandas as pd
import yahooquery as yq
from tqdm import tqdm
from model.model import Model

# %%
num_years=100 # years
bounds=(0.0, 1.0) # percent
gamma=0.0 # decimal
min_weight=0.0 # percent
margin_rate=0.0 # percent
long_weight=1.0 # percent
short_weight=0.0 # percent
frequency=252 # periods per year
period='max' # '1d', '5d', '7d', '60d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max'
api_source='bloomberg' # yahoo or bloomberg
market_symbol='SPY US Equity' # benchmark index ticker
etf_path='https://raw.githubusercontent.com/nathanramoscfa/nrcapital/main/data/etf_cape_return_forecast.csv'
stock_path='https://raw.githubusercontent.com/nathanramoscfa/nrcapital/main/data/stock_cape_return_forecast.csv'

# %%
def get_equity_etf_data(min_long_return=0.15, max_short_return=0.0):
    """
    :description: Get equity ETF data and filter ETFs by expected return
    
    :param min_long_return: Minimum required long return, default is 0.15
    :type min_long_return: float, optional
    :param max_short_return: Maximum tolerable short return, default is 0.0
    :type max_short_return: float, optional
    :return: Selected equity ETFs
    :rtype: tuple
    """
    equity_etf_csv = pd.read_csv(r'https://raw.githubusercontent.com/nathanramoscfa/nrcapital/main/data/etf_cape_return_forecast.csv')
    
    selected_equity_etfs = equity_etf_csv[
        (equity_etf_csv['FWD_RETURN_FORECAST'] >= min_long_return) |
        (equity_etf_csv['FWD_RETURN_FORECAST'] <= max_short_return)
    ]

    return selected_equity_etfs

# %%
selected_equity_etfs = get_equity_etf_data()
selected_equity_etfs
# Out:
#     TICKER                                             NAME  \
# 59     QQQ                       Invesco QQQ Trust Series 1
# 63     OIH                          VanEck Oil Services ETF
# 85    PSCD  Invesco S&P SmallCap Consumer Discretionary ETF
# 88     IJR                   iShares Core S&P Small-Cap ETF
# 89     FYX         First Trust Small Cap Core AlphaDEX Fund
# 90     SLY                        SPDR S&P 600 Small CapETF
# 91    SPSM             SPDR Portfolio S&P 600 Small Cap ETF
# 92    VIOO                   Vanguard S&P Small-Cap 600 ETF
# 93     IJT             iShares S&P Small-Cap 600 Growth ETF
# 94    SLYG                SPDR S&P 600 Small Cap Growth ETF
# 95    VIOG            Vanguard S&P Small-Cap 600 Growth ETF
# 96     IJS              iShares S&P Small-Cap 600 Value ETF
# 97    SLYV                  SPDR S&P 600 Small CapValue ETF
# 98    VIOV             Vanguard S&P Small-Cap 600 Value ETF
# 128   IUSV                  iShares Core S&P U.S. Value ETF
# 129    IVE                        iShares S&P 500 Value ETF
# 130   SPYV                 SPDR Portfolio S&P 500 Value ETF
# 131   VOOV                       Vanguard S&P 500 Value ETF
#
#                                          INDEX_NAME   CAPE  \
# 59                                       NASDAQ-100  38.45
# 63   Philadelphia Stock Exchange Oil Service Sector  10.66
# 85            S&P 600 Consumer Discretionary Sector  14.77
# 88                                S&P Small Cap 600  18.16
# 89                                S&P Small Cap 600  18.16
# 90                                S&P Small Cap 600  18.16
# 91                                S&P Small Cap 600  18.16
# 92                                S&P Small Cap 600  18.16
# 93                         S&P Small Cap 600 Growth  25.79
# 94                         S&P Small Cap 600 Growth  25.79
# 95                         S&P Small Cap 600 Growth  25.79
# 96                          S&P Small Cap 600 Value  14.10
# 97                          S&P Small Cap 600 Value  14.10
# 98                          S&P Small Cap 600 Value  14.10
# 128                                   S&P 500 Value  21.31
# 129                                   S&P 500 Value  21.31
# 130                                   S&P 500 Value  21.31
# 131                                   S&P 500 Value  21.31
#
#      FWD_RETURN_FORECAST  LOWER_CONFIDENCE  UPPER_CONFIDENCE  F_PVALUE  \
# 59                0.1505            0.0704            0.2305       0.0
# 63               -0.1411           -0.3837            0.1021       0.0
# 85                0.1830            0.0680            0.2966       0.0
# 88                0.1708            0.1032            0.2387       0.0
# 89                0.1708            0.1032            0.2387       0.0
# 90                0.1708            0.1032            0.2387       0.0
# 91                0.1708            0.1032            0.2387       0.0
# 92                0.1708            0.1032            0.2387       0.0
# 93                0.1623            0.0899            0.2357       0.0
# 94                0.1623            0.0899            0.2357       0.0
# 95                0.1623            0.0899            0.2357       0.0
# 96                0.1742            0.1086            0.2381       0.0
# 97                0.1742            0.1086            0.2381       0.0
# 98                0.1742            0.1086            0.2381       0.0
# 128              -0.0213           -0.1099            0.0667       0.0
# 129              -0.0213           -0.1099            0.0667       0.0
# 130              -0.0213           -0.1099            0.0667       0.0
# 131              -0.0213           -0.1099            0.0667       0.0
#
#     INDEX_TICKER  MINIMUM_CAPE  MAXIMUM_CAPE  RSQUARED
# 59           NDQ         23.39        117.24    0.7340
# 63           OSX          6.04         58.94    0.3270
# 85        S6COND          9.02         30.87    0.5731
# 88           SML         11.78         31.38    0.6503
# 89           SML         11.78         31.38    0.6503
# 90           SML         11.78         31.38    0.6503
# 91           SML         11.78         31.38    0.6503
# 92           SML         11.78         31.38    0.6503
# 93          SMLG         14.37         45.65    0.6276
# 94          SMLG         14.37         45.65    0.6276
# 95          SMLG         14.37         45.65    0.6276
# 96          SMLV         10.09         26.30    0.7373
# 97          SMLV         10.09         26.30    0.7373
# 98          SMLV         10.09         26.30    0.7373
# 128          SVX          7.94         21.43    0.4879
# 129          SVX          7.94         21.43    0.4879
# 130          SVX          7.94         21.43    0.4879
# 131          SVX          7.94         21.43    0.4879

# %%
symbols = list(selected_equity_etfs.TICKER)

# %%
model = Model(
    symbols,
    num_years,
    bounds,
    gamma,
    min_weight,
    margin_rate,
    long_weight,
    short_weight,
    frequency,
    period,
    api_source,
    market_symbol
)

# %%
historical_prices = model.get_historical_prices()
historical_prices
# Out:
#                SPYV      VOOV       QQQ       OIH     PSCD       IJR      FYX  \
# date
# 2013-07-09  16.6846   60.1778   66.9662  758.1178  38.7086   41.4368  38.1594
# 2013-07-10  16.6668   60.0813   67.3511  753.0816  38.6690   41.5069  38.2331
# 2013-07-12  16.9099   60.9171   68.9911  759.2929  39.1901   41.9754  38.7771
# 2013-07-15  16.9656   61.2144   69.1468  758.2857  39.2639   42.1724  38.9799
# 2013-07-16  16.8895   60.9091   69.0552  751.4029  38.8815   41.9973  38.8140
# ...             ...       ...       ...       ...      ...       ...      ...
# 2023-02-24  40.3600  145.3600  291.8500  309.9500  91.4100  102.1900  85.4400
# 2023-02-27  40.4300  145.5800  293.9400  314.7300  91.3916  102.4200  85.9400
# 2023-02-28  40.3600  145.3400  293.5600  310.9000  91.6300  102.3900  85.9800
# 2023-03-01  40.1800  144.6500  291.2000  319.3900  91.0700  102.6300  85.8559
# 2023-03-02  40.4900  145.9100  293.6100  326.0600  91.6260  102.9400  86.3100
#
#                 SLY     SPSM      VIOO       IJT     SLYG      VIOG       IJS  \
# date
# 2013-07-09  35.9226  17.1958   75.9744   46.5595  30.8365   79.8006   42.4989
# 2013-07-10  36.0651  17.2471   76.1257   46.5732  30.8992   79.9005   42.6073
# 2013-07-12  36.4846  17.5893   77.0958   47.1457  31.3342   80.9456   43.0453
# 2013-07-15  36.6587  17.6720   77.3717   47.2905  31.4252   81.1105   43.3185
# 2013-07-16  36.4213  17.6406   77.0246   47.0679  31.2774   80.5701   43.1711
# ...             ...      ...       ...       ...      ...       ...       ...
# 2023-02-24  88.7700  39.8900  187.2700  114.8600  76.9300  197.6354  100.2200
# 2023-02-27  88.9213  40.0200  187.6900  115.2700  77.1500  198.3049  100.3500
# 2023-02-28  88.8800  39.9800  187.4500  114.8800  76.9400  197.8500  100.4500
# 2023-03-01  88.9600  40.0800  187.9600  115.1200  77.1000  198.2544  100.7500
# 2023-03-02  89.3000  40.2100  188.4000  115.4100  77.2700  198.6181  101.1500
#
#                SLYV      VIOV     IUSV       IVE
# date
# 2013-07-09  34.2291   72.5748  30.1147   62.6401
# 2013-07-10  34.3240   72.7989  30.0391   62.5599
# 2013-07-12  34.7073   73.6441  30.5217   63.4421
# 2013-07-15  34.9404   74.0925  30.6424   63.6667
# 2013-07-16  34.8018   73.8166  30.4596   63.4100
# ...             ...       ...      ...       ...
# 2023-02-24  81.4800  172.9400  73.4600  150.5200
# 2023-02-27  81.6200  173.2800  73.6200  150.7500
# 2023-02-28  81.7500  173.4800  73.4400  150.4800
# 2023-03-01  81.9200  173.9600  73.1800  149.7800
# 2023-03-02  82.2700  175.1400  73.7300  151.0000
#
# [2381 rows x 18 columns]

# %%
risk_free_rate = model.get_risk_free_rate(prints=True)
# Out:
# Risk Free Rate: 3.97%

# %%
market_caps = model.get_market_caps(prints=True)
# Out:
# Market Cap ($Millions):
# QQQ     $159,144.14
# IJR      $72,385.80
# IVE      $25,490.79
# SPYV     $16,272.75
# IUSV     $13,263.05
# IJS       $8,404.13
# IJT       $5,381.09
# SPSM      $5,338.18
# SLYV      $4,348.92
# VOOV      $3,210.95
# OIH       $2,686.97
# SLYG      $2,494.77
# VIOO      $2,405.20
# SLY       $1,853.23
# VIOV      $1,411.68
# FYX         $867.97
# VIOG        $541.61
# PSCD         $25.66
# Name: CUR_MKT_CAP, dtype: object

# %%
vif_symbols = model.vif_filter(historical_prices, market_caps, threshold=50, prints=True)
# Out:
# VIF Tickers:
# TICKER
# OIH      2.39
# QQQ      4.28
# PSCD     4.38
# SPYV     6.79
# VIOG    26.82
# VIOV    29.25
# SPSM    29.87
# FYX     32.60
# Name: VIF Factor, dtype: float64

# %%
investor_views, confidences = model.investor_views_confidences(selected_equity_etfs, vif_symbols, prints=True)
# Out:
# Investor Views:
# TICKER
# PSCD     18.30%
# VIOV     17.42%
# FYX      17.08%
# SPSM     17.08%
# VIOG     16.23%
# QQQ      15.05%
# SPYV     -2.13%
# OIH     -14.11%
# Name: Investor Views, dtype: object
#
# View Confidences:
# TICKER
# VIOV    73.73%
# QQQ     73.40%
# FYX     65.03%
# SPSM    65.03%
# VIOG    62.76%
# PSCD    57.31%
# SPYV    48.79%
# OIH     32.70%
# Name: Confidences, dtype: object

# %%
market_symbol, market_name, market_prices = model.calculate_market_prices(historical_prices, vif_symbols, prints=True)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 market_symbol, market_name, market_prices = model.calculate_market_prices(historical_prices, vif_symbols, prints=True)
#
# File G:\My Drive\etradebot\model\model.py:283, in Model.calculate_market_prices(self, prices, vif_symbols, prints)
#     280     market_prices.index = pd.to_datetime(market_prices.index).date
#     282 elif self.api_source == 'bloomberg':
# --> 283     market_name = self.mgr[self.market_symbol].LONG_COMP_NAME
#     284     market_prices = self.mgr[self.market_symbol].get_historical(
#     285         'PX_LAST',
#     286         start=prices[vif_symbols].index[0],
#     287         end=prices[vif_symbols].index[-1]
#     288     ).squeeze()
#     290 if prints:
#
# File ~\anaconda3\envs\etradebot\Lib\site-packages\tia\bbg\datamgr.py:32, in SidAccessor.__getattribute__(self, item)
#      30 """Access bloomberg fields directly by using all upper case field names"""
#      31 if item.isupper():
# ---> 32     return self.get_attributes(item, **self.overrides)
#      33 else:
#      34     return object.__getattribute__(self, item)
#
# File ~\anaconda3\envs\etradebot\Lib\site-packages\tia\bbg\datamgr.py:37, in SidAccessor.get_attributes(self, flds, **overrides)
#      36 def get_attributes(self, flds, **overrides):
# ---> 37     frame = self.mgr.get_attributes(self.sid, flds, **overrides)
#      38     if self.mgr.sid_result_mode == 'frame':
#      39         return frame
#
# File ~\anaconda3\envs\etradebot\Lib\site-packages\tia\bbg\datamgr.py:149, in BbgDataManager.get_attributes(self, sids, flds, **overrides)
#     148 def get_attributes(self, sids, flds, **overrides):
# --> 149     return self.terminal.get_reference_data(sids, flds, **overrides).as_frame()
#
# File ~\anaconda3\envs\etradebot\Lib\site-packages\tia\bbg\v3api.py:745, in Terminal.get_reference_data(self, sids, flds, ignore_security_error, ignore_field_error, **overrides)
#     742 def get_reference_data(self, sids, flds, ignore_security_error=0, ignore_field_error=0, **overrides):
#     743     req = ReferenceDataRequest(sids, flds, ignore_security_error=ignore_security_error,
#     744                                ignore_field_error=ignore_field_error, **overrides)
# --> 745     return self.execute(req)
#
# File ~\anaconda3\envs\etradebot\Lib\site-packages\tia\bbg\v3api.py:729, in Terminal.execute(self, request)
#     727         else:
#     728             request.on_admin_event(evt)
# --> 729     request.has_exception and request.raise_exception()
#     730     return request.response
#     731 finally:
#
# File ~\anaconda3\envs\etradebot\Lib\site-packages\tia\bbg\v3api.py:215, in Request.raise_exception(self)
#     213 if not self.ignore_security_error and len(self.security_errors) > 0:
#     214     msgs = ['(%s, %s, %s)' % (s.security, s.category, s.message) for s in self.security_errors]
# --> 215     raise Exception('SecurityError: %s' % ','.join(msgs))
#     216 if not self.ignore_field_error and len(self.field_errors) > 0:
#     217     msgs = ['(%s, %s, %s, %s)' % (s.security, s.field, s.category, s.message) for s in self.field_errors]
#
# Exception: SecurityError: (SPY US Equity US Equity, BAD_SEC, Unknown/Invalid Security  [nid:19488])

# %%
market_implied_risk_aversion = model.market_implied_risk_aversion(market_prices, risk_free_rate, prints=True)

# %%
covariance_matrix = model.calculate_covariance_matrix(historical_prices, vif_symbols, prints=True)

# %%
posterior_covariance_matrix, posterior_expected_returns = model.calculate_black_litterman(
    covariance_matrix,
    market_prices, 
    risk_free_rate, 
    market_caps, 
    vif_symbols, 
    investor_views,
    confidences, 
    prints=True
)

# %%
min_volatility, min_weights, min_results = model.minimum_risk_portfolio(
    posterior_expected_returns, posterior_covariance_matrix, risk_free_rate, prints=True
)

# %%
max_volatility, max_weights, max_results = model.maximum_risk_portfolio(
    posterior_expected_returns, posterior_covariance_matrix, risk_free_rate, prints=True
)

# %%
max_sharpe_weights, max_sharpe_results = model.maximum_sharpe_portfolio(
    posterior_expected_returns, posterior_covariance_matrix, risk_free_rate, prints=True
)

# %%
portfolios, results = model.efficient_frontier_portfolios(
    posterior_expected_returns, posterior_covariance_matrix, risk_free_rate, prints=False
)
portfolios

# %%
results

# %%
model.plot_efficient_frontier(posterior_expected_returns, results, covariance_matrix, figsize=(12, 6))
