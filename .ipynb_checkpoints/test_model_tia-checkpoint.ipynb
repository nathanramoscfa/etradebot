# %% [markdown]
# # Model Testing

# %%
import pandas as pd
import yahooquery as yq
import model.views as views
from tqdm import tqdm
from model.model import Model

# %%
num_years=100 # years
bounds=(0.0, 1.0) # percent
gamma=0.0 # decimal
min_weight=0.0 # percent
margin_rate=0.0 # percent
long_weight=1.0 # percent
short_weight=0.0 # percent
frequency=252 # periods per year
period='max' # '1d', '5d', '7d', '60d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max'
api_source='bloomberg' # yahoo or bloomberg
market_symbol='SPY US Equity' # benchmark index ticker
etf_path='https://raw.githubusercontent.com/nathanramoscfa/nrcapital/main/data/etf_cape_return_forecast.csv'
stock_path='https://raw.githubusercontent.com/nathanramoscfa/nrcapital/main/data/stock_cape_return_forecast.csv'

# %%
def get_nrcapital_forecast(filepath, min_long_return=0.15, max_short_return=0.0):
    """
    :description: Get equity ETF data and filter ETFs by expected return
    
    :param filepath: Filepath to nrcapital forecasts
    :type filepath: str, required
    :param min_long_return: Minimum required long return, default is 0.15
    :type min_long_return: float, optional
    :param max_short_return: Maximum tolerable short return, default is 0.0
    :type max_short_return: float, optional
    :return: Selected equity ETFs
    :rtype: tuple
    """
    equity_etf_csv = pd.read_csv(r'{}'.format(filepath))
    
    selected_equity_etfs = equity_etf_csv[
        (equity_etf_csv['FWD_RETURN_FORECAST'] >= min_long_return) |
        (equity_etf_csv['FWD_RETURN_FORECAST'] <= max_short_return)
    ]

    return selected_equity_etfs

# %%
selected_equity_etfs = get_nrcapital_forecast(etf_path)
selected_equity_etfs
# Out:
#     TICKER                                             NAME  \
# 59     QQQ                       Invesco QQQ Trust Series 1
# 63     OIH                          VanEck Oil Services ETF
# 85    PSCD  Invesco S&P SmallCap Consumer Discretionary ETF
# 88     IJR                   iShares Core S&P Small-Cap ETF
# 89     FYX         First Trust Small Cap Core AlphaDEX Fund
# 90     SLY                        SPDR S&P 600 Small CapETF
# 91    SPSM             SPDR Portfolio S&P 600 Small Cap ETF
# 92    VIOO                   Vanguard S&P Small-Cap 600 ETF
# 93     IJT             iShares S&P Small-Cap 600 Growth ETF
# 94    SLYG                SPDR S&P 600 Small Cap Growth ETF
# 95    VIOG            Vanguard S&P Small-Cap 600 Growth ETF
# 96     IJS              iShares S&P Small-Cap 600 Value ETF
# 97    SLYV                  SPDR S&P 600 Small CapValue ETF
# 98    VIOV             Vanguard S&P Small-Cap 600 Value ETF
# 128   IUSV                  iShares Core S&P U.S. Value ETF
# 129    IVE                        iShares S&P 500 Value ETF
# 130   SPYV                 SPDR Portfolio S&P 500 Value ETF
# 131   VOOV                       Vanguard S&P 500 Value ETF
#
#                                          INDEX_NAME   CAPE  \
# 59                                       NASDAQ-100  37.17
# 63   Philadelphia Stock Exchange Oil Service Sector  12.59
# 85            S&P 600 Consumer Discretionary Sector  13.75
# 88                                S&P Small Cap 600  16.70
# 89                                S&P Small Cap 600  16.70
# 90                                S&P Small Cap 600  16.70
# 91                                S&P Small Cap 600  16.70
# 92                                S&P Small Cap 600  16.70
# 93                         S&P Small Cap 600 Growth  23.40
# 94                         S&P Small Cap 600 Growth  23.40
# 95                         S&P Small Cap 600 Growth  23.40
# 96                          S&P Small Cap 600 Value  13.00
# 97                          S&P Small Cap 600 Value  13.00
# 98                          S&P Small Cap 600 Value  13.00
# 128                                   S&P 500 Value  20.03
# 129                                   S&P 500 Value  20.03
# 130                                   S&P 500 Value  20.03
# 131                                   S&P 500 Value  20.03
#
#      FWD_RETURN_FORECAST  LOWER_CONFIDENCE  UPPER_CONFIDENCE  F_PVALUE  \
# 59                0.1581            0.0782            0.2380       0.0
# 63               -0.1153           -0.3585            0.1270       0.0
# 85                0.2029            0.0893            0.3175       0.0
# 88                0.1942            0.1265            0.2619       0.0
# 89                0.1942            0.1265            0.2619       0.0
# 90                0.1942            0.1265            0.2619       0.0
# 91                0.1942            0.1265            0.2619       0.0
# 92                0.1942            0.1265            0.2619       0.0
# 93                0.1867            0.1133            0.2588       0.0
# 94                0.1867            0.1133            0.2588       0.0
# 95                0.1867            0.1133            0.2588       0.0
# 96                0.2002            0.1349            0.2643       0.0
# 97                0.2002            0.1349            0.2643       0.0
# 98                0.2002            0.1349            0.2643       0.0
# 128              -0.0078           -0.0959            0.0810       0.0
# 129              -0.0078           -0.0959            0.0810       0.0
# 130              -0.0078           -0.0959            0.0810       0.0
# 131              -0.0078           -0.0959            0.0810       0.0
#
#     INDEX_TICKER  MINIMUM_CAPE  MAXIMUM_CAPE  RSQUARED
# 59           NDQ         23.39        117.24    0.7340
# 63           OSX          6.04         58.94    0.3248
# 85        S6COND          9.02         30.87    0.5729
# 88           SML         11.78         31.38    0.6498
# 89           SML         11.78         31.38    0.6498
# 90           SML         11.78         31.38    0.6498
# 91           SML         11.78         31.38    0.6498
# 92           SML         11.78         31.38    0.6498
# 93          SMLG         14.37         45.65    0.6282
# 94          SMLG         14.37         45.65    0.6282
# 95          SMLG         14.37         45.65    0.6282
# 96          SMLV         10.09         26.30    0.7360
# 97          SMLV         10.09         26.30    0.7360
# 98          SMLV         10.09         26.30    0.7360
# 128          SVX          7.94         21.43    0.4832
# 129          SVX          7.94         21.43    0.4832
# 130          SVX          7.94         21.43    0.4832
# 131          SVX          7.94         21.43    0.4832

# %%
symbols = list(selected_equity_etfs.TICKER)

# %%
model = Model(
    symbols,
    num_years,
    bounds,
    gamma,
    min_weight,
    margin_rate,
    long_weight,
    short_weight,
    frequency,
    period,
    api_source,
    market_symbol
)

# %%
historical_prices = model.get_historical_prices()
historical_prices
# Out:
#                  QQQ       OIH     PSCD       IJR      FYX      SLY     SPSM  \
# date
# 2013-07-09   66.9662  758.1178  38.7086   41.4368  38.1594  35.9226  17.1958
# 2013-07-10   67.3511  753.0816  38.6690   41.5069  38.2331  36.0651  17.2471
# 2013-07-12   68.9911  759.2929  39.1901   41.9754  38.7771  36.4846  17.5893
# 2013-07-15   69.1468  758.2857  39.2639   42.1724  38.9799  36.6587  17.6720
# 2013-07-16   69.0552  751.4029  38.8815   41.9973  38.8140  36.4213  17.6406
# ...              ...       ...      ...       ...      ...      ...      ...
# 2023-03-08  297.8200  317.0600  91.0200  100.9400  84.9191  87.6800  39.4000
# 2023-03-09  292.6600  301.9800  89.5040   98.6400  82.3800  85.6400  38.5100
# 2023-03-10  288.5500  294.3900  87.1200   96.1700  80.2384  83.5000  37.5200
# 2023-03-13  290.6900  281.5300  84.9700   93.8400  78.1781  81.4500  36.6300
# 2023-03-14  297.3700  283.4600  86.0500   95.7500  79.5549  83.0100  37.4000
#
#                VIOO       IJT     SLYG     VIOG      IJS     SLYV     VIOV  \
# date
# 2013-07-09  37.9872   46.5595  30.8365  39.9003  42.4989  34.2291  36.2874
# 2013-07-10  38.0629   46.5732  30.8992  39.9502  42.6073  34.3240  36.3994
# 2013-07-12  38.5479   47.1457  31.3342  40.4728  43.0453  34.7073  36.8220
# 2013-07-15  38.6858   47.2905  31.4252  40.5553  43.3185  34.9404  37.0463
# 2013-07-16  38.5123   47.0679  31.2774  40.2850  43.1711  34.8018  36.9083
# ...             ...       ...      ...      ...      ...      ...      ...
# 2023-03-08  92.4750  113.5500  76.0100  97.6851  98.8900  80.4200  85.4050
# 2023-03-09  90.3100  111.1000  74.3600  95.6800  96.4500  78.4200  83.3050
# 2023-03-10  88.0000  108.5300  72.6400  93.2363  93.8800  76.3900  80.9892
# 2023-03-13  85.8600  106.2800  71.0000  91.3786  91.3200  74.2500  78.8300
# 2023-03-14  87.7300  108.6100  72.6900  93.4697  92.9800  75.6200  80.2700
#
#                IUSV       IVE     SPYV      VOOV
# date
# 2013-07-09  30.1147   62.6401  16.6846   60.1778
# 2013-07-10  30.0391   62.5599  16.6668   60.0813
# 2013-07-12  30.5217   63.4421  16.9099   60.9171
# 2013-07-15  30.6424   63.6667  16.9656   61.2144
# 2013-07-16  30.4596   63.4100  16.8895   60.9091
# ...             ...       ...      ...       ...
# 2023-03-08  73.4900  150.7200  40.4200  145.5600
# 2023-03-09  71.9400  147.5700  39.5600  142.4600
# 2023-03-10  70.7500  145.2900  38.9700  140.2700
# 2023-03-13  70.2100  144.2100  38.6800  139.2400
# 2023-03-14  71.3500  146.5900  39.3200  141.6700
#
# [2389 rows x 18 columns]

# %%
risk_free_rate = model.get_risk_free_rate(prints=True)
# Out:
# Risk Free Rate: 3.66%

# %%
market_caps = model.get_market_caps(prints=True)
# Out:
# Market Cap ($Millions):
# QQQ     $159,524.14
# IJR      $66,843.08
# IVE      $24,341.27
# SPYV     $15,295.59
# IUSV     $12,686.03
# IJS       $7,429.10
# SPSM      $5,024.69
# IJT       $4,974.34
# SLYV      $3,924.84
# VOOV      $3,084.86
# SLYG      $2,340.62
# OIH       $2,338.70
# VIOO      $2,232.74
# SLY       $1,716.24
# VIOV      $1,288.33
# FYX         $791.57
# VIOG        $509.41
# PSCD         $27.54
# Name: CUR_MKT_CAP, dtype: object

# %%
market_caps
# Out:
# FYX        791.571411
# IJR      66843.078125
# IJS       7429.102051
# IJT       4974.337891
# IUSV     12686.029297
# IVE      24341.269531
# OIH       2338.698730
# PSCD        27.536001
# QQQ     159524.140625
# SLY       1716.235596
# SLYG      2340.620117
# SLYV      3924.837158
# SPSM      5024.690430
# SPYV     15295.592773
# VIOG       509.409882
# VIOO      2232.735107
# VIOV      1288.333496
# VOOV      3084.864258
# Name: CUR_MKT_CAP, dtype: float64

# %%
vif_symbols = model.vif_filter(historical_prices, market_caps, threshold=50, prints=True)
# Out:
# VIF Tickers:
# TICKER
# OIH      2.40
# QQQ      4.29
# PSCD     4.38
# SPYV     6.79
# VIOG    26.93
# VIOV    29.25
# SPSM    30.04
# FYX     32.55
# Name: VIF Factor, dtype: float64

# %%
investor_views, confidences = views.investor_views_confidences(selected_equity_etfs, vif_symbols, prints=True)
# Out:
# Investor Views:
# TICKER
# PSCD     20.29%
# VIOV     20.02%
# FYX      19.42%
# SPSM     19.42%
# VIOG     18.67%
# QQQ      15.81%
# SPYV     -0.78%
# OIH     -11.53%
# Name: Investor Views, dtype: object
#
# View Confidences:
# TICKER
# VIOV    73.60%
# QQQ     73.40%
# FYX     64.98%
# SPSM    64.98%
# VIOG    62.82%
# PSCD    57.29%
# SPYV    48.32%
# OIH     32.48%
# Name: Confidences, dtype: object

# %%
market_symbol, market_name, market_prices = model.calculate_market_prices(historical_prices, vif_symbols, prints=True)
# Out:
# Market Symbol: SPY US Equity
# Market Name: SPDR S&P 500 ETF Trust
#
# Market Prices:
# date
# 2013-07-09    $138.49
# 2013-07-10    $138.54
# 2013-07-11    $140.42
# 2013-07-12    $140.48
# 2013-07-15    $141.02
#                ...
# 2023-03-08    $398.92
# 2023-03-09    $391.56
# 2023-03-10    $385.91
# 2023-03-13    $385.36
# 2023-03-14    $391.73
# Name: SPDR S&P 500 ETF Trust, Length: 2438, dtype: object

# %%
market_implied_risk_aversion = model.market_implied_risk_aversion(market_prices, risk_free_rate, prints=True)
# Out:
# Market Implied Risk Aversion:
# Delta: 2.79

# %%
covariance_matrix = model.calculate_covariance_matrix(historical_prices, vif_symbols, prints=True)
# Out:
# Covariance Matrix:
#          FYX     OIH    PSCD     QQQ    SPSM    SPYV    VIOG    VIOV
# FYX   0.0565  0.0702  0.0560  0.0379  0.0518  0.0363  0.0511  0.0528
# OIH   0.0702  0.1852  0.0620  0.0383  0.0639  0.0499  0.0579  0.0692
# PSCD  0.0560  0.0620  0.0759  0.0370  0.0531  0.0346  0.0525  0.0540
# QQQ   0.0379  0.0383  0.0370  0.0475  0.0364  0.0298  0.0381  0.0332
# SPSM  0.0518  0.0639  0.0531  0.0364  0.0505  0.0344  0.0485  0.0497
# SPYV  0.0363  0.0499  0.0346  0.0298  0.0344  0.0305  0.0336  0.0348
# VIOG  0.0511  0.0579  0.0525  0.0381  0.0485  0.0336  0.0497  0.0480
# VIOV  0.0528  0.0692  0.0540  0.0332  0.0497  0.0348  0.0480  0.0525

# %%
posterior_covariance_matrix, posterior_expected_returns = model.calculate_black_litterman(
    covariance_matrix,
    market_prices, 
    risk_free_rate, 
    market_caps, 
    vif_symbols, 
    investor_views,
    confidences, 
    prints=True
)
# Out:
# Delta:
# 2.79
#
# Prior Expected Returns:
# QQQ     16.34%
# OIH     15.44%
# FYX     14.48%
# VIOG    14.38%
# PSCD    14.20%
# SPSM    14.02%
# VIOV    13.28%
# SPYV    12.11%
# dtype: object
#
# Posterior Expected Returns:
# PSCD    19.16%
# FYX     17.51%
# VIOG    17.46%
# SPSM    16.99%
# VIOV    16.37%
# QQQ     16.23%
# OIH     11.94%
# SPYV    11.26%
# dtype: object

# %%
min_volatility, min_weights, min_results = model.minimum_risk_portfolio(
    posterior_expected_returns, posterior_covariance_matrix, risk_free_rate, prints=True
)
# Out:
# Minimum Risk Portfolio:
# Minimum Volatility: 17.54%
#
# Weights:
# SPYV    95.20%
# QQQ      4.80%
# Name: Minimum Risk Portfolio, dtype: object
#
# Results:
# Expected_Return        11.50%
# Expected Volatility    17.54%
# Sharpe_Ratio           0.4468
# Name: Results, dtype: object
#
# Long/Short Ratio:
# Portfolio weights sum: 100.0%
# Long weights sum: 100.0%
# Short weights sum: 0.0%

# %%
max_volatility, max_weights, max_results = model.maximum_risk_portfolio(
    posterior_expected_returns, posterior_covariance_matrix, risk_free_rate, prints=True
)
# Out:
# Maximum Risk Portfolio:
# Maximum Volatility: 27.71%
#
# Weights:
# PSCD    100.00%
# Name: Maximum Risk Portfolio, dtype: object
#
# Results:
# Expected_Return        19.16%
# Expected Volatility    27.71%
# Sharpe_Ratio           0.5594
# Name: Results, dtype: object
#
# Long/Short Ratio:
# Portfolio weights sum: 100.0%
# Long weights sum: 100.0%
# Short weights sum: 0.0%

# %%
max_sharpe_weights, max_sharpe_results = model.maximum_sharpe_portfolio(
    posterior_expected_returns, posterior_covariance_matrix, risk_free_rate, prints=True
)
# Out:
# Maximum Sharpe Portfolio:
# Sharpe Ratio: 0.641
#
# Weights:
# VIOG    39.60%
# QQQ     39.40%
# PSCD    21.00%
# Name: Maximum Sharpe Portfolio, dtype: object
#
# Results:
# Expected_Return        17.33%
# Expected Volatility    21.33%
# Sharpe_Ratio            0.641
# Name: Results, dtype: object
#
# Long/Short Ratio:
# Portfolio weights sum: 100.0%
# Long weights sum: 100.0%
# Short weights sum: 0.0%
# C:\Users\25del\anaconda3\envs\etradebot\Lib\site-packages\pypfopt\efficient_frontier\efficient_frontier.py:257: UserWarning: max_sharpe transforms the optimization problem so additional objectives may not work as expected.
#   warnings.warn(

# %%
portfolios, results = model.efficient_frontier_portfolios(
    posterior_expected_returns, posterior_covariance_matrix, risk_free_rate, prints=False
)
portfolios
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 107.70it/s]
#             1       2       3       4       5       6       7       8   \
# TICKER
# FYX     0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# OIH     0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# PSCD    0.0000  0.0510  0.0678  0.0817  0.0875  0.0926  0.0973  0.2053
# QQQ     0.1855  0.2727  0.3148  0.3496  0.3916  0.4299  0.4662  0.3969
# SPSM    0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0052  0.0000
# SPYV    0.8145  0.6149  0.4674  0.3460  0.2240  0.1136  0.0083  0.0000
# VIOG    0.0000  0.0614  0.1499  0.2228  0.2527  0.2787  0.3011  0.3978
# VIOV    0.0000  0.0000  0.0000  0.0000  0.0441  0.0852  0.1220  0.0000
#
#             9       10      11      12      13      14      15      16  \
# TICKER
# FYX     0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# OIH     0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# PSCD    0.3198  0.4055  0.4797  0.5446  0.6053  0.6607  0.7141  0.7640
# QQQ     0.3267  0.2742  0.2287  0.1889  0.1518  0.1178  0.0851  0.0545
# SPSM    0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# SPYV    0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# VIOG    0.3535  0.3203  0.2915  0.2664  0.2429  0.2215  0.2008  0.1815
# VIOV    0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#             17      18      19     20
# TICKER
# FYX     0.0000  0.0000  0.0000  0.000
# OIH     0.0000  0.0000  0.0000  0.000
# PSCD    0.8128  0.8615  0.9266  0.988
# QQQ     0.0247  0.0000  0.0000  0.000
# SPSM    0.0000  0.0000  0.0000  0.000
# SPYV    0.0000  0.0000  0.0000  0.000
# VIOG    0.1626  0.1385  0.0734  0.012
# VIOV    0.0000  0.0000  0.0000  0.000

# %%
results
# Out:
#                          1       2       3       4       5       6       7   \
# Expected_Return      0.1218  0.1340  0.1429  0.1502  0.1569  0.1629  0.1686
# Expected Volatility  0.1764  0.1816  0.1869  0.1921  0.1974  0.2026  0.2079
# Sharpe_Ratio         0.4830  0.5362  0.5687  0.5915  0.6094  0.6234  0.6351
#
#                          8       9       10      11      12      13      14  \
# Expected_Return      0.1732  0.1760  0.1781  0.1800  0.1815  0.1830  0.1844
# Expected Volatility  0.2131  0.2184  0.2236  0.2289  0.2341  0.2394  0.2446
# Sharpe_Ratio         0.6410  0.6384  0.6330  0.6263  0.6192  0.6117  0.6043
#
#                          15      16      17      18      19      20
# Expected_Return      0.1857  0.1869  0.1881  0.1893  0.1904  0.1914
# Expected Volatility  0.2499  0.2551  0.2604  0.2656  0.2709  0.2761
# Sharpe_Ratio         0.5967  0.5893  0.5820  0.5748  0.5677  0.5608

# %%
model.plot_efficient_frontier(posterior_expected_returns, results, covariance_matrix, figsize=(12, 6))
