# %% [markdown]
# # Model Testing

# %%
import pandas as pd
import yahooquery as yq
import model.views as views
from model.model import Model
from tqdm import tqdm

# %%
num_years=100 # years
bounds=(0.0, 1.0) # percent
gamma=0.0 # decimal
min_weight=0.0 # percent
margin_rate=0.0 # percent
long_weight=1.0 # percent
short_weight=0.0 # percent
frequency=252 # periods per year
period=None # '1d', '5d', '7d', '60d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max'
api_source='yahoo' # yahoo or bloomberg
market_symbol='^GSPC' # benchmark index ticker
etf_path='https://raw.githubusercontent.com/nathanramoscfa/nrcapital/main/data/etf_cape_return_forecast.csv'
stock_path='https://raw.githubusercontent.com/nathanramoscfa/nrcapital/main/data/stock_cape_return_forecast.csv'

# %%
def get_nrcapital_forecast(filepath, min_long_return=0.15, max_short_return=0.0):
    """
    :description: Get equity ETF data and filter ETFs by expected return
    
    :param filepath: Filepath to nrcapital forecasts
    :type filepath: str, required
    :param min_long_return: Minimum required long return, default is 0.15
    :type min_long_return: float, optional
    :param max_short_return: Maximum tolerable short return, default is 0.0
    :type max_short_return: float, optional
    :return: Selected equity ETFs
    :rtype: tuple
    """
    equity_etf_csv = pd.read_csv(r'{}'.format(filepath))
    
    selected_equity_etfs = equity_etf_csv[
        (equity_etf_csv['FWD_RETURN_FORECAST'] >= min_long_return) |
        (equity_etf_csv['FWD_RETURN_FORECAST'] <= max_short_return)
    ]

    return selected_equity_etfs

# %%
selected_equity_etfs = get_nrcapital_forecast(etf_path)
selected_equity_etfs
# Out:
#     TICKER                                             NAME  \
# 59     QQQ                       Invesco QQQ Trust Series 1
# 63     OIH                          VanEck Oil Services ETF
# 85    PSCD  Invesco S&P SmallCap Consumer Discretionary ETF
# 88     IJR                   iShares Core S&P Small-Cap ETF
# 89     FYX         First Trust Small Cap Core AlphaDEX Fund
# 90     SLY                        SPDR S&P 600 Small CapETF
# 91    SPSM             SPDR Portfolio S&P 600 Small Cap ETF
# 92    VIOO                   Vanguard S&P Small-Cap 600 ETF
# 93     IJT             iShares S&P Small-Cap 600 Growth ETF
# 94    SLYG                SPDR S&P 600 Small Cap Growth ETF
# 95    VIOG            Vanguard S&P Small-Cap 600 Growth ETF
# 96     IJS              iShares S&P Small-Cap 600 Value ETF
# 97    SLYV                  SPDR S&P 600 Small CapValue ETF
# 98    VIOV             Vanguard S&P Small-Cap 600 Value ETF
# 128   IUSV                  iShares Core S&P U.S. Value ETF
# 129    IVE                        iShares S&P 500 Value ETF
# 130   SPYV                 SPDR Portfolio S&P 500 Value ETF
# 131   VOOV                       Vanguard S&P 500 Value ETF
#
#                                          INDEX_NAME   CAPE  \
# 59                                       NASDAQ-100  37.17
# 63   Philadelphia Stock Exchange Oil Service Sector  12.59
# 85            S&P 600 Consumer Discretionary Sector  13.75
# 88                                S&P Small Cap 600  16.70
# 89                                S&P Small Cap 600  16.70
# 90                                S&P Small Cap 600  16.70
# 91                                S&P Small Cap 600  16.70
# 92                                S&P Small Cap 600  16.70
# 93                         S&P Small Cap 600 Growth  23.40
# 94                         S&P Small Cap 600 Growth  23.40
# 95                         S&P Small Cap 600 Growth  23.40
# 96                          S&P Small Cap 600 Value  13.00
# 97                          S&P Small Cap 600 Value  13.00
# 98                          S&P Small Cap 600 Value  13.00
# 128                                   S&P 500 Value  20.03
# 129                                   S&P 500 Value  20.03
# 130                                   S&P 500 Value  20.03
# 131                                   S&P 500 Value  20.03
#
#      FWD_RETURN_FORECAST  LOWER_CONFIDENCE  UPPER_CONFIDENCE  F_PVALUE  \
# 59                0.1581            0.0782            0.2380       0.0
# 63               -0.1153           -0.3585            0.1270       0.0
# 85                0.2029            0.0893            0.3175       0.0
# 88                0.1942            0.1265            0.2619       0.0
# 89                0.1942            0.1265            0.2619       0.0
# 90                0.1942            0.1265            0.2619       0.0
# 91                0.1942            0.1265            0.2619       0.0
# 92                0.1942            0.1265            0.2619       0.0
# 93                0.1867            0.1133            0.2588       0.0
# 94                0.1867            0.1133            0.2588       0.0
# 95                0.1867            0.1133            0.2588       0.0
# 96                0.2002            0.1349            0.2643       0.0
# 97                0.2002            0.1349            0.2643       0.0
# 98                0.2002            0.1349            0.2643       0.0
# 128              -0.0078           -0.0959            0.0810       0.0
# 129              -0.0078           -0.0959            0.0810       0.0
# 130              -0.0078           -0.0959            0.0810       0.0
# 131              -0.0078           -0.0959            0.0810       0.0
#
#     INDEX_TICKER  MINIMUM_CAPE  MAXIMUM_CAPE  RSQUARED
# 59           NDQ         23.39        117.24    0.7340
# 63           OSX          6.04         58.94    0.3248
# 85        S6COND          9.02         30.87    0.5729
# 88           SML         11.78         31.38    0.6498
# 89           SML         11.78         31.38    0.6498
# 90           SML         11.78         31.38    0.6498
# 91           SML         11.78         31.38    0.6498
# 92           SML         11.78         31.38    0.6498
# 93          SMLG         14.37         45.65    0.6282
# 94          SMLG         14.37         45.65    0.6282
# 95          SMLG         14.37         45.65    0.6282
# 96          SMLV         10.09         26.30    0.7360
# 97          SMLV         10.09         26.30    0.7360
# 98          SMLV         10.09         26.30    0.7360
# 128          SVX          7.94         21.43    0.4832
# 129          SVX          7.94         21.43    0.4832
# 130          SVX          7.94         21.43    0.4832
# 131          SVX          7.94         21.43    0.4832

# %%
symbols = list(selected_equity_etfs.TICKER)

# %%
model = Model(
    symbols,
    num_years,
    bounds,
    gamma,
    min_weight,
    margin_rate,
    long_weight,
    short_weight,
    frequency,
    period,
    api_source,
    market_symbol
)

# %%
historical_prices = model.get_historical_prices()
historical_prices
# Out:
# symbol             QQQ         OIH       PSCD         IJR        FYX  \
# 2013-07-09   67.063828  758.085815  38.710983   41.438255  38.158886
# 2013-07-10   67.449188  753.049805  38.674576   41.508308  38.232658
# 2013-07-11   68.788811  755.567932  39.157101   41.893665  38.610649
# 2013-07-12   69.091614  759.260803  39.193516   41.976868  38.776611
# 2013-07-15   69.247589  758.253723  39.266342   42.173908  38.979424
# ...                ...         ...        ...         ...        ...
# 2023-03-06  300.019989  329.440002  90.690002  101.779999  86.059998
# 2023-03-07  296.339996  322.309998  90.690002  100.769997  84.900002
# 2023-03-08  297.820007  317.059998  91.019997  100.940002  84.919998
# 2023-03-09  292.660004  301.980011  89.500000   98.639999  82.379997
# 2023-03-10  288.549988  294.390015  87.120003   96.169998  80.239998
#
# symbol            SLY       SPSM        VIOO         IJT       SLYG  \
# 2013-07-09  35.993683  17.158161   75.974014   46.559158  30.867720
# 2013-07-10  36.136440  17.209379   76.125305   46.572895  30.930513
# 2013-07-11  36.477463  17.209379   76.766068   47.021770  31.216108
# 2013-07-12  36.556778  17.550770   77.095329   47.145439  31.365995
# 2013-07-15  36.731243  17.633278   77.371201   47.292019  31.457127
# ...               ...        ...         ...         ...        ...
# 2023-03-06  88.269997  39.750000  186.229996  114.440002  76.639999
# 2023-03-07  87.379997  39.349998  184.559998  113.290001  75.849998
# 2023-03-08  87.680000  39.400002  184.949997  113.550003  76.010002
# 2023-03-09  85.639999  38.509998  180.619995  111.099998  74.360001
# 2023-03-10  83.500000  37.520000  176.000000  108.529999  72.639999
#
# symbol            VIOG        IJS       SLYV        VIOV       IUSV  \
# 2013-07-09   79.799896  42.498215  34.255413   72.573822  30.114031
# 2013-07-10   79.900665  42.606632  34.350330   72.798019  30.038969
# 2013-07-11   80.395287  43.005596  34.689854   73.539627  30.465223
# 2013-07-12   80.944862  43.044628  34.733665   73.643105  30.521524
# 2013-07-15   81.109749  43.317825  34.967323   74.091499  30.642157
# ...                ...        ...        ...         ...        ...
# 2023-03-06  197.009995  99.720001  81.099998  171.899994  74.650002
# 2023-03-07  195.190002  98.739998  80.260002  170.380005  73.410004
# 2023-03-08  195.369995  98.889999  80.419998  170.809998  73.489998
# 2023-03-09  191.360001  96.449997  78.419998  166.610001  71.940002
# 2023-03-10  186.470001  93.879997  76.389999  161.979996  70.750000
#
# symbol             IVE       SPYV        VOOV
# 2013-07-09   62.640202  16.684055   60.176933
# 2013-07-10   62.560020  16.666323   60.080509
# 2013-07-11   63.338001  16.883028   60.884041
# 2013-07-12   63.442257  16.908640   60.916183
# 2013-07-15   63.666851  16.965763   61.213501
# ...                ...        ...         ...
# 2023-03-06  153.039993  41.049999  147.779999
# 2023-03-07  150.559998  40.360001  145.389999
# 2023-03-08  150.720001  40.419998  145.559998
# 2023-03-09  147.570007  39.560001  142.460007
# 2023-03-10  145.289993  38.970001  140.270004
#
# [2436 rows x 18 columns]

# %%
risk_free_rate = model.get_risk_free_rate(prints=True)
# Out:
# Risk Free Rate: 3.52%

# %%
market_caps = model.get_market_caps(prints=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 18/18 [00:02<00:00,  7.29it/s]
# Market Cap ($Millions):
# QQQ     $156,738.93
# IJR      $70,965.96
# IVE      $25,099.48
# SPYV     $16,012.22
# IUSV     $13,053.21
# IJS       $8,239.30
# IJT       $5,337.29
# SPSM      $5,201.33
# VIOO      $4,367.23
# SLYV      $4,253.76
# VOOV      $3,351.99
# OIH       $2,453.94
# SLYG      $2,450.59
# SLY       $1,803.68
# VIOV      $1,439.23
# FYX         $853.09
# VIOG        $534.55
# PSCD         $26.55
# dtype: object

# %%
yq_ticker = yq.Ticker(['SPY'], api_source='yahoo')
yq_summary_detail = yq_ticker.summary_detail
yq_summary_detail
# Out:
# {'SPY': {'maxAge': 1,
#   'priceHint': 2,
#   'previousClose': 385.91,
#   'open': 381.81,
#   'dayLow': 380.67,
#   'dayHigh': 390.39,
#   'regularMarketPreviousClose': 385.91,
#   'regularMarketOpen': 381.81,
#   'regularMarketDayLow': 380.67,
#   'regularMarketDayHigh': 390.39,
#   'trailingPE': 19.329405,
#   'volume': 157789967,
#   'regularMarketVolume': 157789967,
#   'averageVolume': 85957027,
#   'averageVolume10days': 108580080,
#   'averageDailyVolume10Day': 108580080,
#   'bid': 0.0,
#   'ask': 0.0,
#   'bidSize': 900,
#   'askSize': 900,
#   'yield': 0.0194,
#   'totalAssets': 359626440704,
#   'fiftyTwoWeekLow': 348.11,
#   'fiftyTwoWeekHigh': 462.07,
#   'fiftyDayAverage': 399.108,
#   'twoHundredDayAverage': 393.11615,
#   'trailingAnnualDividendRate': 5.662,
#   'trailingAnnualDividendYield': 0.014671815,
#   'navPrice': 391.58377,
#   'currency': 'USD',
#   'fromCurrency': None,
#   'toCurrency': None,
#   'lastMarket': None,
#   'coinMarketCapLink': None,
#   'algorithm': None,
#   'tradeable': False}}

# %%
yq_price = yq_ticker.price
yq_price
# Out:
# {'SPY': {'maxAge': 1,
#   'preMarketSource': 'FREE_REALTIME',
#   'postMarketChangePercent': 0.0009602077,
#   'postMarketChange': 0.37002563,
#   'postMarketTime': '2023-03-13 18:59:58',
#   'postMarketPrice': 385.73,
#   'postMarketSource': 'DELAYED',
#   'regularMarketChangePercent': -0.00142525,
#   'regularMarketChange': -0.550018,
#   'regularMarketTime': '2023-03-13 15:00:04',
#   'priceHint': 2,
#   'regularMarketPrice': 385.36,
#   'regularMarketDayHigh': 390.39,
#   'regularMarketDayLow': 380.67,
#   'regularMarketVolume': 157789967,
#   'regularMarketPreviousClose': 385.91,
#   'regularMarketSource': 'FREE_REALTIME',
#   'regularMarketOpen': 381.81,
#   'exchange': 'PCX',
#   'exchangeName': 'NYSEArca',
#   'exchangeDataDelayedBy': 0,
#   'marketState': 'PREPRE',
#   'quoteType': 'ETF',
#   'symbol': 'SPY',
#   'underlyingSymbol': None,
#   'shortName': 'SPDR S&P 500',
#   'longName': 'SPDR S&P 500 ETF Trust',
#   'currency': 'USD',
#   'currencySymbol': '$',
#   'fromCurrency': None,
#   'toCurrency': None,
#   'lastMarket': None,
#   'marketCap': 353676460032}}

# %%
vif_symbols = model.vif_filter(historical_prices, market_caps, threshold=50, prints=True)
# Out:
# VIF Tickers:
# TICKER
# OIH      2.38
# PSCD     4.10
# QQQ      4.23
# SPYV     6.62
# IJS     19.43
# VIOG    25.89
# SPSM    26.70
# FYX     31.97
# VIOV    38.42
# Name: VIF Factor, dtype: float64

# %%
investor_views, confidences = views.investor_views_confidences(selected_equity_etfs, vif_symbols, prints=True)
# Out:
# Investor Views:
# TICKER
# PSCD     20.29%
# IJS      20.02%
# VIOV     20.02%
# FYX      19.42%
# SPSM     19.42%
# VIOG     18.67%
# QQQ      15.81%
# SPYV     -0.78%
# OIH     -11.53%
# Name: Investor Views, dtype: object
#
# View Confidences:
# TICKER
# IJS     73.60%
# VIOV    73.60%
# QQQ     73.40%
# FYX     64.98%
# SPSM    64.98%
# VIOG    62.82%
# PSCD    57.29%
# SPYV    48.32%
# OIH     32.48%
# Name: Confidences, dtype: object

# %%
market_symbol, market_name, market_prices = model.calculate_market_prices(historical_prices, vif_symbols, prints=True)
# Out:
# Market Symbol: ^GSPC
# Market Name: S&P 500
#
# Market Prices:
# 2013-07-09    $1,652.32
# 2013-07-10    $1,652.62
# 2013-07-11    $1,675.02
# 2013-07-12    $1,680.19
# 2013-07-15    $1,682.50
#                 ...
# 2023-03-03    $4,045.64
# 2023-03-06    $4,048.42
# 2023-03-07    $3,986.37
# 2023-03-08    $3,992.01
# 2023-03-09    $3,918.32
# Name: ^GSPC, Length: 2435, dtype: object

# %%
market_implied_risk_aversion = model.market_implied_risk_aversion(market_prices, risk_free_rate, prints=True)
# Out:
# Market Implied Risk Aversion:
# Delta: 2.21

# %%
covariance_matrix = model.calculate_covariance_matrix(historical_prices, vif_symbols, prints=True)
# Out:
# Covariance Matrix:
# symbol     QQQ     OIH    PSCD     FYX    SPSM    VIOG     IJS    VIOV    SPYV
# symbol
# QQQ     0.0462  0.0363  0.0355  0.0366  0.0350  0.0368  0.0307  0.0319  0.0287
# OIH     0.0363  0.1771  0.0586  0.0667  0.0607  0.0550  0.0654  0.0658  0.0473
# PSCD    0.0355  0.0586  0.0745  0.0538  0.0509  0.0505  0.0505  0.0518  0.0331
# FYX     0.0366  0.0667  0.0538  0.0543  0.0497  0.0492  0.0492  0.0507  0.0348
# SPSM    0.0350  0.0607  0.0509  0.0497  0.0487  0.0467  0.0461  0.0477  0.0330
# VIOG    0.0368  0.0550  0.0505  0.0492  0.0467  0.0480  0.0445  0.0463  0.0323
# IJS     0.0307  0.0654  0.0505  0.0492  0.0461  0.0445  0.0493  0.0484  0.0322
# VIOV    0.0319  0.0658  0.0518  0.0507  0.0477  0.0463  0.0484  0.0506  0.0334
# SPYV    0.0287  0.0473  0.0331  0.0348  0.0330  0.0323  0.0322  0.0334  0.0293

# %%
posterior_covariance_matrix, posterior_expected_returns = model.calculate_black_litterman(
    covariance_matrix,
    market_prices, 
    risk_free_rate, 
    market_caps, 
    vif_symbols, 
    investor_views,
    confidences, 
    prints=True
)
# Out:
# Delta:
# 2.21
#
# Prior Expected Returns:
# symbol
# QQQ     13.12%
# OIH     12.65%
# FYX     11.90%
# VIOG    11.79%
# PSCD    11.68%
# SPSM    11.53%
# VIOV    11.01%
# IJS     10.76%
# SPYV    10.00%
# dtype: object
#
# Posterior Expected Returns:
# symbol
# PSCD    19.81%
# FYX     18.16%
# VIOG    17.85%
# SPSM    17.54%
# VIOV    17.25%
# IJS     17.05%
# QQQ     15.61%
# OIH     12.65%
# SPYV    10.00%
# dtype: object

# %%
min_volatility, min_weights, min_results = model.minimum_risk_portfolio(
    posterior_expected_returns, posterior_covariance_matrix, risk_free_rate, prints=True
)
# Out:
# Minimum Risk Portfolio:
# Minimum Volatility: 17.2%
#
# Weights:
# SPYV    95.78%
# QQQ      4.22%
# Name: Minimum Risk Portfolio, dtype: object
#
# Results:
# Expected_Return        10.24%
# Expected Volatility    17.20%
# Sharpe_Ratio           0.3906
# Name: Results, dtype: object
#
# Long/Short Ratio:
# Portfolio weights sum: 100.0%
# Long weights sum: 100.0%
# Short weights sum: 0.0%

# %%
max_volatility, max_weights, max_results = model.maximum_risk_portfolio(
    posterior_expected_returns, posterior_covariance_matrix, risk_free_rate, prints=True
)
# Out:
# Maximum Risk Portfolio:
# Maximum Volatility: 27.44%
#
# Weights:
# PSCD    100.00%
# Name: Maximum Risk Portfolio, dtype: object
#
# Results:
# Expected_Return        19.81%
# Expected Volatility    27.44%
# Sharpe_Ratio           0.5936
# Name: Results, dtype: object
#
# Long/Short Ratio:
# Portfolio weights sum: 100.0%
# Long weights sum: 100.0%
# Short weights sum: 0.0%

# %%
max_sharpe_weights, max_sharpe_results = model.maximum_sharpe_portfolio(
    posterior_expected_returns, posterior_covariance_matrix, risk_free_rate, prints=True
)
# Out:
# Maximum Sharpe Portfolio:
# Sharpe Ratio: 0.6656
#
# Weights:
# VIOG    43.30%
# QQQ     24.96%
# PSCD    19.32%
# IJS     12.41%
# Name: Maximum Sharpe Portfolio, dtype: object
#
# Results:
# Expected_Return        17.57%
# Expected Volatility    21.11%
# Sharpe_Ratio           0.6656
# Name: Results, dtype: object
#
# Long/Short Ratio:
# Portfolio weights sum: 99.99%
# Long weights sum: 99.99%
# Short weights sum: 0.0%
# C:\Users\25del\anaconda3\envs\etradebot\Lib\site-packages\pypfopt\efficient_frontier\efficient_frontier.py:257: UserWarning: max_sharpe transforms the optimization problem so additional objectives may not work as expected.
#   warnings.warn(

# %%
portfolios, results = model.efficient_frontier_portfolios(
    posterior_expected_returns, posterior_covariance_matrix, risk_free_rate, prints=False
)
portfolios
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 111.48it/s]
#             1       2       3       4       5       6       7       8   \
# TICKER
# QQQ     0.1635  0.2634  0.3296  0.3708  0.4066  0.4401  0.3428  0.2636
# OIH     0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# PSCD    0.0000  0.0030  0.0147  0.0172  0.0194  0.0214  0.1106  0.1808
# FYX     0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# SPSM    0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# VIOG    0.0000  0.0000  0.0019  0.0442  0.0810  0.1153  0.2817  0.4103
# IJS     0.0158  0.1696  0.2645  0.3196  0.3676  0.4123  0.2649  0.1453
# VIOV    0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# SPYV    0.8207  0.5640  0.3892  0.2482  0.1254  0.0109  0.0000  0.0000
#
#             9       10      11      12      13      14      15      16  \
# TICKER
# QQQ     0.1985  0.1320  0.0656  0.0052  0.0000  0.0000  0.0000  0.0000
# OIH     0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# PSCD    0.2386  0.2934  0.3447  0.3913  0.4876  0.5721  0.6480  0.7183
# FYX     0.0000  0.0000  0.0000  0.0000  0.0000  0.0285  0.0571  0.0836
# SPSM    0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# VIOG    0.5161  0.5746  0.5897  0.6035  0.5124  0.3994  0.2948  0.1981
# IJS     0.0469  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# VIOV    0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
# SPYV    0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000  0.0000
#
#             17      18      19      20
# TICKER
# QQQ     0.0000  0.0000  0.0000  0.0000
# OIH     0.0000  0.0000  0.0000  0.0000
# PSCD    0.7830  0.8455  0.9163  0.9869
# FYX     0.1081  0.1316  0.0837  0.0131
# SPSM    0.0000  0.0000  0.0000  0.0000
# VIOG    0.1090  0.0228  0.0000  0.0000
# IJS     0.0000  0.0000  0.0000  0.0000
# VIOV    0.0000  0.0000  0.0000  0.0000
# SPYV    0.0000  0.0000  0.0000  0.0000

# %%
results
# Out:
#                          1       2       3       4       5       6       7   \
# Expected_Return      0.1103  0.1270  0.1387  0.1485  0.1570  0.1649  0.1709
# Expected Volatility  0.1730  0.1783  0.1836  0.1889  0.1941  0.1994  0.2047
# Sharpe_Ratio         0.4340  0.5150  0.5639  0.5997  0.6274  0.6505  0.6627
#
#                          8       9       10      11      12      13      14  \
# Expected_Return      0.1750  0.1783  0.1813  0.1838  0.1860  0.1880  0.1898
# Expected Volatility  0.2100  0.2153  0.2206  0.2258  0.2311  0.2364  0.2417
# Sharpe_Ratio         0.6655  0.6648  0.6621  0.6579  0.6527  0.6465  0.6396
#
#                          15      16      17      18      19      20
# Expected_Return      0.1914  0.1928  0.1942  0.1955  0.1967  0.1979
# Expected Volatility  0.2470  0.2523  0.2575  0.2628  0.2681  0.2734
# Sharpe_Ratio         0.6322  0.6247  0.6174  0.6099  0.6024  0.5950

# %%
model.plot_efficient_frontier(posterior_expected_returns, results, covariance_matrix, figsize=(12, 6))
